# %% [markdown]
# <a href="https://colab.research.google.com/github/JMML2021/0601_Statistics/blob/main/0601_Statistic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import scipy.stats as stats
import numpy as np
warnings.filterwarnings('ignore')

# %%
# Activo Google Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '/content/drive/MyDrive/01_COLAB/kaggle.json'

# %%
df = pd.read_csv("../input/world-marathons-majors/world_marathon_majors.csv",encoding='ISO-8859-1')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-46-df9ebcf91797> in <module>()
# ----> 1 df = pd.read_csv("../input/world-marathons-majors/world_marathon_majors.csv",encoding='ISO-8859-1')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
# Abro el fichero una vez adecuado


path = ('/content/drive/MyDrive/01_COLAB/world_marathon_majors.csv')
#path =('https://drive.google.com/file/d/1dFd1lDtoONb2dC_kmJ-qVtZc1J_mpmrx/view?usp=sharingpath')
df=  pd.read_csv(path, encoding='ISO-8859-1')
df.shape

nRow, nCol = df.shape
print(f'\n\nHay  {nRow} filas con {nCol} columnas')
# Out:
# Hay  536 filas con 6 columnas

# %%
df.head()
# Out:
#    year              winner  gender   country      time marathon
# 0  2018      Dickson Chumba    Male     Kenya  02:05:30    Tokyo
# 1  2018      Birhane Dibaba  Female  Ethiopia  02:19:51    Tokyo
# 2  2017      Wilson Kipsang    Male     Kenya  02:03:58    Tokyo
# 3  2017  Sarah Chepchirchir  Female     Kenya  02:19:47    Tokyo
# 4  2016       Feyisa Lilesa    Male  Ethiopia  02:06:56    Tokyo

# %%
resultado['resultado']= df['home_score']
resultado.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-5bd9e09f330b> in <module>()
# ----> 1 resultado['resultado']= df['home_score']
#       2 resultado.head()
#
# NameError: name 'resultado' is not defined

# %%
def time_to_second(time):
    hour = int(time.split(':')[0])
    minute = int(time.split(':')[1])
    second = int(time.split(':')[2])
    return ((hour* 60*60 + minute *60 + second)*1)
    
df1['second'] = df['time'].map(time_to_second)

# %%
df1
# Out:
#      year              winner  gender        country      time marathon  \
# 0    2018      Dickson Chumba    Male          Kenya  02:05:30    Tokyo
# 1    2018      Birhane Dibaba  Female       Ethiopia  02:19:51    Tokyo
# 2    2017      Wilson Kipsang    Male          Kenya  02:03:58    Tokyo
# 3    2017  Sarah Chepchirchir  Female          Kenya  02:19:47    Tokyo
# 4    2016       Feyisa Lilesa    Male       Ethiopia  02:06:56    Tokyo
# ..    ...                 ...     ...            ...       ...      ...
# 531  1978      Mark Stanforth    Male  United States  02:19:20  Chicago
# 532  1978        Lynae Larson  Female  United States  02:59:25  Chicago
# 533  1977         Dan Cloeter    Male  United States  02:17:52  Chicago
# 534  1977   Dorothy Doolittle  Female  United States  02:50:47  Chicago
# 535  2018    Vivian Cheruiyot  Female          Kenya  02:18:31   London
#
#      second
# 0      7530
# 1      8391
# 2      7438
# 3      8387
# 4      7616
# ..      ...
# ...

# %%
df1.describe()
# Out:
#               year        second
# count   536.000000    536.000000
# mean   1987.919776   8489.744403
# std      26.104662    856.994681
# min    1897.000000   7377.000000
# 25%    1980.000000   7783.000000
# 50%    1993.000000   8467.500000
# 75%    2007.000000   8856.250000
# max    2018.000000  12600.000000

# %%
def time_to_hours(segundos):
    segundos = int(segundos)

    horas = int(segundos / 60 / 60)
    segundos -= horas*60*60
    minutos = int(segundos/60)
    segundos -= minutos*60
    return f"{horas:02d}:{minutos:02d}:{segundos:02d}"

# %%
#df1=df.copy()


print('la media es: ', time_to_hours(df1['second'].mean()) )
# Out:
# la media es:  02:21:29

# %% [markdown]
# # - Exercici 1
# Agafa un conjunt de dades de tema esportiu que t'agradi i selecciona un atribut del conjunt de dades. Calcula la moda, la mediana, la desviació estàndard i la mitjana aritmètica.

# %%
 
print('la media es: ', time_to_hours(df1['second'].mean()))
print('la mediana es: ', time_to_hours(df1['second'].median()) )
print('La moda es: ', time_to_hours(np.std(df1['second'])))
print("la desv std es: ", time_to_hours(np.std(df1['second'])))
# Out:
# la media es:  02:21:29
# la mediana es:  02:21:07
# La moda es:  00:14:16
# la desv std es:  00:14:16

# %% [markdown]
# ***Nota:*** hay que indicar que el calulo está hecho de un modo poco ortodosporque.
# 1.- Los datos no son normales.
# 2.- Los datos están autocrrelacionados entre si.
# 3.- Hay dos poblaciones.

# %%
# Out:
#      year              winner  gender        country      time marathon  \
# 0    2018      Dickson Chumba    Male          Kenya  02:05:30    Tokyo
# 1    2018      Birhane Dibaba  Female       Ethiopia  02:19:51    Tokyo
# 2    2017      Wilson Kipsang    Male          Kenya  02:03:58    Tokyo
# 3    2017  Sarah Chepchirchir  Female          Kenya  02:19:47    Tokyo
# 4    2016       Feyisa Lilesa    Male       Ethiopia  02:06:56    Tokyo
# ..    ...                 ...     ...            ...       ...      ...
# 531  1978      Mark Stanforth    Male  United States  02:19:20  Chicago
# 532  1978        Lynae Larson  Female  United States  02:59:25  Chicago
# 533  1977         Dan Cloeter    Male  United States  02:17:52  Chicago
# 534  1977   Dorothy Doolittle  Female  United States  02:50:47  Chicago
# 535  2018    Vivian Cheruiyot  Female          Kenya  02:18:31   London
#
#      second
# 0      7530
# 1      8391
# 2      7438
# 3      8387
# 4      7616
# ..      ...
# ...

# %% [markdown]
# # Nivell 2
# - Exercici 3
# Continuant amb les dades de tema esportiu, calcula la correlació de tots els atributs entre sí i representa'ls en una matriu amb diferents colors d'intensitat.

# %%
sns.scatterplot(x = 'year', y = 'second', data = df1, hue='gender', s = 100);

# %% [markdown]
# Base de datos del Maraton
#
# https://www.kaggle.com/code/jeongbinpark/world-marathons-analysis

# %%
# Creo una tabla separando los sexos
df2= df1.pivot_table(index = "year", columns = "gender", values = "second")
df2
# Out:
# gender       Female          Male
# year
# 1897            NaN  10510.000000
# 1898            NaN   9720.000000
# 1899            NaN  10478.000000
# 1900            NaN   9584.000000
# 1901            NaN   8963.000000
# ...             ...           ...
# 2014    8508.857143   7569.166667
# 2015    8589.000000   7639.666667
# 2016    8604.500000   7650.500000
# 2017    8444.500000   7631.333333
# 2018    8765.333333   7715.000000
#
# [121 rows x 2 columns]

# %%
# Gráfico
# ==============================================================================

df2=df2.dropna() 
fig, ax = plt.subplots(1, 1, figsize=(6,4))
ax.scatter(x= df2.Female, y=df2.Male, alpha= 0.8)
ax.set_xlabel('home_score')
ax.set_ylabel('away_score');

# %%
# Gráfico
# ==============================================================================
fig, ax = plt.subplots(1, 1, figsize=(6,4))
ax.scatter(x= df2.Female, y=df2.Male, alpha= 0.8)
ax.set_xlabel('home_score')
ax.set_ylabel('away_score');

# %% [markdown]
# Como podemos ver hay correlacion entre el tiempo que tarda una mujer y el tiempo que tarda un hombre en hacer el maraton.
# Y tiene logica porque ls técnicas de peraracion son similares.
#
# Para confirmalos vamos a calculas el valor de r y el p_value.
#
#
# Al valor de r untilizaremos esta tabla:
#
# 0: asociación nula.
#
# 0.1: asociación pequeña.
#
# 0.3: asociación mediana.
#
# 0.5: asociación moderada.
#
# 0.7: asociación alta.
#
# 0.9: asociación muy alta.
#
# https://www.cienciadedatos.net/documentos/pystats05-correlacion-lineal-python.html

# %%
 df2=df2.dropna() 
# Cálculo de correlación con Pandas
# ==============================================================================
print('Correlación Pearson: ', df2.Male.corr(df2.Female, method='pearson'))
print('Correlación spearman: ', df2.Male.corr(df2.Female, method='spearman'))
print('Correlación kendall: ', df2.Male.corr(df2.Female, method='kendall'))
# Out:
# Correlación Pearson:  0.8272779062657023
# Correlación spearman:  0.9219666581186667
# Correlación kendall:  0.7629764567953651

# %% [markdown]
# La corelacion es alta r= 0.8

# %%
# Cálculo de correlación y significancia con Scipy
# ==============================================================================
r, p = stats.pearsonr(df2.Female, df2.Male)
print(f"Correlación Pearson: r={r}, p-value={p}")

r, p = stats.spearmanr(df2.Female, df2.Male)
print(f"Correlación Spearman: r={r}, p-value={p}")

r, p = stats.kendalltau(df2.Female, df2.Male)
print(f"Correlación Pearson: r={r}, p-value={p}")
# Out:
# Correlación Pearson: r=0.8272779062657025, p-value=2.2545521687714287e-14
# Correlación Spearman: r=0.9219666581186668, p-value=1.1709570772612221e-22
# Correlación Pearson: r=0.7629764567953651, p-value=7.496668924052681e-16

# %% [markdown]
# ***Conclusion:***
# La correlacion es alta, r>0.8
# y el valor de p_value es muy bajo ( < 0.05)luesgo estadistica está correlacionado

# %% [markdown]
# # Nivell 2
# ## Exercici 3
# Continuant amb les dades de tema esportiu, calcula la correlació de tots els atributs entre sí i representa'ls en una matriu amb diferents colors d'intensitat.

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))# Creo una tabla separando los sexos

# %%
# Creo una tabla separando los sexos
df2= df1.pivot_table(index = "year", columns = "gender", values = "second")

df2= pd.DataFrame(df2)
df2 = df2.reset_index()
df2
# Out:
# gender  year       Female          Male
# 0       1897          NaN  10510.000000
# 1       1898          NaN   9720.000000
# 2       1899          NaN  10478.000000
# 3       1900          NaN   9584.000000
# 4       1901          NaN   8963.000000
# ..       ...          ...           ...
# 116     2014  8508.857143   7569.166667
# 117     2015  8589.000000   7639.666667
# 118     2016  8604.500000   7650.500000
# 119     2017  8444.500000   7631.333333
# 120     2018  8765.333333   7715.000000
#
# [121 rows x 3 columns]

# %%
# Variables numéricas
datos = df2.select_dtypes(include=['float64', 'int'])

# Matriz de correlación
# ==============================================================================
corr_matrix = datos.corr(method='pearson')
corr_matrix
# Out:
# gender      year    Female      Male
# gender
# year    1.000000 -0.819672 -0.871471
# Female -0.819672  1.000000  0.827278
# Male   -0.871471  0.827278  1.000000

# %%
# Heatmap matriz de correlaciones
# ==============================================================================
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5, 5))

sns.heatmap(
    corr_matrix,
    annot     = True,
    cbar      = False,
    annot_kws = {"size": 8},
    vmin      = -1,
    vmax      = 1,
    center    = 0,
    cmap      = sns.diverging_palette(20, 220, n=200),
    square    = True,
    ax        = ax
)

ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation = 45,
    horizontalalignment = 'right',
)

ax.tick_params(labelsize = 10)

# %% [markdown]
# # **Conclusión:**
#
# Este grafico nos indica que las correlaciones año v Male es la mas alta
#
#
# https://www.cienciadedatos.net/documentos/pystats05-correlacion-lineal-python.html

# %% [markdown]
# # Nivell 3
# ## Exercici 4
# Continuant amb les dades de tema esportiu, selecciona un atribut i calcula la mitjana geomètrica i la mitjana harmònica.

# %% [markdown]
# En este artículo, discutiremos cómo encontrar la media geométrica de un DataFrame dado. Generalmente, la media geométrica de los números n es la raíz n de su producto.
#
# ![image.png](data:image/png;base64,...)

# %%
 df2=df2.dropna() 
df2['Geometric Mean'] = stats.gmean(df2.iloc[:, 1:3], axis=1) 
df2['Geometric Mean'] = stats.gmean(df2.iloc[:, 0:3], axis=1) 
df2.head()
# Out:
# gender  year   Female    Male  Geometric Mean
# 68      1966  12100.0  8231.0     5806.848496
# 69      1967  12437.0  8145.0     5840.773446
# 70      1968  12600.0  8537.0     5959.826820
# 71      1969  12166.0  8029.0     5772.336787
# 72      1970  11107.0  8464.0     5700.061624

# %%
# !pip install scipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Harmonic Mean of the  column in dataframe
from scipy import stats
 
df2['harmonica Mean']=stats.hmean(df2.iloc[:,0:3],axis=1)
df2.head()
# Out:
# gender  year   Female    Male  Geometric Mean  harmonica Mean
# 68      1966  12100.0  8231.0     5806.848496     4208.851353
# 69      1967  12437.0  8145.0     5840.773446     4216.039063
# 70      1968  12600.0  8537.0     5959.826820     4257.539542
# 71      1969  12166.0  8029.0     5772.336787     4198.054044
# 72      1970  11107.0  8464.0     5700.061624     4191.144267
